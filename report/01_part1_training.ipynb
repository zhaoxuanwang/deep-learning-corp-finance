# %% [markdown]
# # Deep Learning Methods for Structural Corporate Finance Models
#
# This notebook demonstrates deep learning methods for solving two dynamic models:
# 1. **Basic model**: Optimal investment policies
# 2. **Risky debt model**: Optimal investment and leverage policies
#
# ## Workflow and Structure
#
# This notebook is organized into three *independent* sections:
#
# 1. **Section 1. Dataset Creation:** Generate synthetic data for training
#     - Use stateless seeds to generate deterministic training and validation data
#     - All methods below will be implemented on the same dataset
# 2. **Section 2. Deep Learning Methods:** Run all models and save checkpoints
#     - Lifetime Reward Maximization (LR)
#     - Euler Equation Residual Minimization (ER)
#     - Bellman Equation Residual Minimization (BR)
# 3. **Section 3. Conventional Methods:** Run all models and save checkpoints
#     - Value Function Iteration (VFI)
#     - Policy Function Iteration (PFI)
#
# Section 1 (Data Generation) is prerequisite. After running it, Section 2 and 3 can be ran independently.
#
# **Key Difference**:
# - **LR Method**: Uses trajectory data (N samples, T+1 timesteps)
# - **ER/BR/VFI/PFI Methods**: Use flattened i.i.d. data (N$\times$T independent transitions)

# %% [markdown]
# ---
#
# # Section 1: Dataset Creation

# %%
# =============================================================================
# 1.1 Imports and Setup
# =============================================================================

import sys
import os
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"  # hide INFO/WARNING C++ logs
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd

# Add project root to path
sys.path.append(os.path.abspath(".."))

from src.economy.data_generator import create_data_generator
from src.economy.parameters import EconomicParams, ShockParams
from src.trainers.config import (
    NetworkConfig, OptimizationConfig, OptimizerConfig,
    AnnealingConfig, MethodConfig, EarlyStoppingConfig,
    RiskyDebtConfig, DataConfig, ExperimentConfig,
    ObservationNormalizationConfig,
)
from src.trainers import train

# %%
# Configure Logging for Notebook Display
from src.utils.logging_config import setup_notebook_logging
setup_notebook_logging('INFO')
# Out:
# Logging configured: level=INFO

# %%
# =============================================================================
# 1.2 Run Configuration & Folder Structure
# =============================================================================
from datetime import datetime

# Configuration options
SAVE_RESULTS = True  # Toggle to enable/disable saving results

# Auto-generate timestamped run name
RUN_NAME = datetime.now().strftime("run-%Y%m%d-%H%M%S")

# Directory paths
RESULTS_BASE = os.path.join("..", "results")
RESULTS_DIR = os.path.join(RESULTS_BASE, RUN_NAME)
LATEST_LINK = os.path.join(RESULTS_BASE, "latest")  # Stable path for reports

DATA_DIR = os.path.join(RESULTS_DIR, "data")
FIGURES_DIR = os.path.join(RESULTS_DIR, "figures")
CHECKPOINTS_DIR = os.path.join(RESULTS_DIR, "checkpoints")

if SAVE_RESULTS:
    # Create directory structure
    for d in [DATA_DIR, FIGURES_DIR, CHECKPOINTS_DIR]:
        os.makedirs(d, exist_ok=True)
    
    # Update 'latest' symlink to point to current run
    if os.path.islink(LATEST_LINK):
        os.unlink(LATEST_LINK)
    elif os.path.exists(LATEST_LINK):
        import shutil
        shutil.rmtree(LATEST_LINK)  # Remove if it's a directory
    os.symlink(RUN_NAME, LATEST_LINK)  # Relative symlink
    
    print(f"Results directory: {RESULTS_DIR}")
    print(f"  - Data:        {DATA_DIR}")
    print(f"  - Figures:     {FIGURES_DIR}")
    print(f"  - Checkpoints: {CHECKPOINTS_DIR}")
    print(f"  - Symlink:     {LATEST_LINK} -> {RUN_NAME}")
else:
    print("SAVE_RESULTS=False: Results will not be saved to disk")
# Out:
# Results directory: ../results/run-20260221-185122
#   - Data:        ../results/run-20260221-185122/data
#   - Figures:     ../results/run-20260221-185122/figures
#   - Checkpoints: ../results/run-20260221-185122/checkpoints
#   - Symlink:     ../results/latest -> run-20260221-185122

# %%
# =============================================================================
# 1.3 Training Configuration
# =============================================================================
# Training profiles for different example use cases:

# Key insights:
# - Sample size = DATA_T * DATA_SIM_BATCH_SIZE * DATA_N_SIM_BATCHES
# - LR has SHORT-HORIZON BIAS if T is too small (keep T >= 32)
# - Reduce trajectories (n_sim_batches) instead of T for speed
# - ER/BR use flattened transitions, so T mainly affects data diversity

# === SELECT PROFILE ===
TRAINING_PROFILE = "BALANCED"  # Options: "FAST_DEBUG", "BALANCED", "PRODUCTION"

if TRAINING_PROFILE == "FAST_DEBUG":
    # Fast debugging with reasonable horizon (avoid short-horizon bias)
    DATA_T = 32                      # Keep T reasonable for LR
    DATA_SIM_BATCH_SIZE = 10         # Fewer trajectories
    DATA_N_SIM_BATCHES = 5           
    # For basic model training
    TRAIN_BATCH_SIZE = 64            
    TRAIN_N_ITER = 300               
    TRAIN_DECAY = 0.99
    # For risky debt model training
    TRAIN_RISKY_BATCH_SIZE = 64
    TRAIN_RISKY_N_ITER = 300
    
elif TRAINING_PROFILE == "BALANCED":
    # Sample size
    DATA_T = 100                      
    DATA_SIM_BATCH_SIZE = 40         
    DATA_N_SIM_BATCHES = 10 
    # For basic model         
    TRAIN_BATCH_SIZE = 64
    TRAIN_N_ITER = 1000
    TRAIN_DECAY = 0.995
    # For risky debt model training
    TRAIN_RISKY_BATCH_SIZE = 128
    TRAIN_RISKY_N_ITER = 1000    
    
else:  # PRODUCTION
    # Full training for final results
    DATA_T = 64                      # Longer horizon for best LR quality
    DATA_SIM_BATCH_SIZE = 100         # 1600 trajectories
    DATA_N_SIM_BATCHES = 25          
    TRAIN_BATCH_SIZE = 128
    TRAIN_N_ITER = 2000
    TRAIN_DECAY = 0.998
    # For risky debt model training
    TRAIN_RISKY_BATCH_SIZE = 512
    TRAIN_RISKY_N_ITER = 2000        

n_trajectories = DATA_SIM_BATCH_SIZE * DATA_N_SIM_BATCHES
n_transitions = n_trajectories * DATA_T

print(f"Training Profile: {TRAINING_PROFILE}")
print(f"  Trajectories: {n_trajectories}, T={DATA_T}")
print(f"  Flattened transitions: {n_transitions:,}")
print(f"  Training Basic: batch_size={TRAIN_BATCH_SIZE}, n_iter={TRAIN_N_ITER}, decay={TRAIN_DECAY}")
print(f"  Training Risky: batch_size={TRAIN_RISKY_BATCH_SIZE}, n_iter={TRAIN_RISKY_N_ITER}")
# Out:
# Training Profile: BALANCED
#   Trajectories: 400, T=100
#   Flattened transitions: 40,000
#   Training Basic: batch_size=64, n_iter=1000, decay=0.995
#   Training Risky: batch_size=128, n_iter=1000

# %%
# =============================================================================
# 1.4 Data Configuration
# =============================================================================

# Set save_to_disk=True for faster restart (loads cached data)
# Set save_to_disk=False to regenerate data each time (default)
SAVE_DATA_TO_DISK = False

data_config = DataConfig(
    master_seed=(20, 26),
    T=DATA_T,  # Use profile-specific horizon
    sim_batch_size=DATA_SIM_BATCH_SIZE,
    n_sim_batches=DATA_N_SIM_BATCHES,
    auto_compute_bounds=True,
    std_dev_multiplier=3.0,
    k_min_multiplier=0.2,
    k_max_multiplier=4.0,
    cache_dir=DATA_DIR,
    save_to_disk=SAVE_DATA_TO_DISK
)

data_config.print_summary()
# Out:
# ============================================================
# DATA CONFIGURATION
# ============================================================
#                                                                  Value
# Group      Parameter
# Simulation master_seed                                        (20, 26)
#            T (horizon)                                             100
#            sim_batch_size                                           40
#            n_sim_batches                                            10
#            total_samples                                           400
#            N_val                                         400 (default)
#            N_test                                       2000 (default)
# Bounds     auto_compute_bounds                                    True
#            std_dev_multiplier (m)                                  3.0
#            k_min_multiplier                                        0.2
#            k_max_multiplier                                        4.0
# Cache      cache_dir               ../results/run-20260221-185122/data
#            save_to_disk                                          False
# ============================================================

# %%
# =============================================================================
# 1.5 Economic Parameters
# =============================================================================

# Base economic parameters (shared across all scenarios)
base_params = EconomicParams()  # Uses defaults

# AR(1) Shock Process (shared across all scenarios)
shock_params = ShockParams(mu=0.0, rho=0.7, sigma=0.15)

# =============================================================================
# SCENARIO DEFINITIONS
# =============================================================================

# Basic Model Scenarios: Vary adjustment cost structure
# All scenarios derive from base_params with specific overrides
BASIC_SCENARIOS = {
    'baseline': {
        'description': 'No adjustment costs',
        'params': base_params.with_overrides(
            cost_convex=0.0,
            cost_fixed=0.0,
            cost_inject_fixed=0.0,
            cost_inject_linear=0.0
        )
    },
    'smooth_cost': {
        'description': 'Convex adjustment costs only',
        'params': base_params.with_overrides(
            cost_convex=0.2,
            cost_fixed=0.0,
            cost_inject_fixed=0.0,
            cost_inject_linear=0.0
        )
    },
    'fixed_cost': {
        'description': 'Fixed adjustment costs only',
        'params': base_params.with_overrides(
            cost_convex=0.0,
            cost_fixed=0.02,
            cost_inject_fixed=0.0,
            cost_inject_linear=0.0
        )
    }
}

# Risky Debt Model: Single baseline scenario
RISKY_SCENARIOS = {
    'baseline': {
        'description': 'Standard risky debt with all cost components',
        'params': base_params.with_overrides(
            cost_convex=0.01,
            cost_fixed=0.01,
            cost_inject_fixed=0.02,
            cost_inject_linear=0.02,
            cost_default=0.4,
            tax=0.3
        )
    }
    # Add more scenarios if needed
}

# Print scenario summary
print("=" * 60)
print("SCENARIO DEFINITIONS")
print("=" * 60)
print(f"\nBase parameters: r={base_params.r_rate}, delta={base_params.delta}, theta={base_params.theta}")
print("\nBasic Model Scenarios:")
for name, scenario in BASIC_SCENARIOS.items():
    p = scenario['params']
    print(f"  {name:12s}: cost_convex={p.cost_convex}, cost_fixed={p.cost_fixed}")
    print(f"               {scenario['description']}")

print("\nRisky Debt Scenarios:")
for name, scenario in RISKY_SCENARIOS.items():
    p = scenario['params']
    print(f"  {name:12s}: cost_convex={p.cost_convex}, cost_fixed={p.cost_fixed}, cost_default={p.cost_default}")
    print(f"               {scenario['description']}")
print("=" * 60)
# Out:
# [INFO] parameters: EconomicParams overrides: cost_convex: 0.0 -> 0.2
# [INFO] parameters: EconomicParams overrides: cost_fixed: 0.0 -> 0.02
# [INFO] parameters: EconomicParams overrides: cost_convex: 0.0 -> 0.01, cost_fixed: 0.0 -> 0.01, cost_inject_fixed: 0.0 -> 0.02, cost_inject_linear: 0.0 -> 0.02
# ============================================================
# SCENARIO DEFINITIONS
# ============================================================
#
# Base parameters: r=0.04, delta=0.15, theta=0.7
#
# Basic Model Scenarios:
#   baseline    : cost_convex=0.0, cost_fixed=0.0
#                No adjustment costs
#   smooth_cost : cost_convex=0.2, cost_fixed=0.0
#                Convex adjustment costs only
#   fixed_cost  : cost_convex=0.0, cost_fixed=0.02
#                Fixed adjustment costs only
#
# Risky Debt Scenarios:
#   baseline    : cost_convex=0.01, cost_fixed=0.01, cost_default=0.4
#                Standard risky debt with all cost components
# ============================================================

# %%
# =============================================================================
# 1.6 Generate Synthetic Data (shared across all scenarios)
# =============================================================================

# Use DataConfig.create_generator()
generator, _, bounds = data_config.create_generator(
    # Use baseline params for data generation (all scenarios train on same data)
    params=base_params,
    shock_params=shock_params,
    verbose=False
)

# Get training data in both formats
traj_data = generator.get_training_dataset()
flat_data = generator.get_flattened_training_dataset(include_debt=True)

# Get validation data
val_traj = generator.get_validation_dataset()
val_flat = generator.get_flattened_validation_dataset(include_debt=True)

print(f"\nTraining: {traj_data['k0'].shape[0]:,} trajectories, {flat_data['k'].shape[0]:,} transitions")
print(f"Validation: {val_traj['k0'].shape[0]:,} trajectories, {val_flat['k'].shape[0]:,} transitions")

# Store bounds for later use
k_bounds = bounds['k']
logz_bounds = bounds['log_z']
b_bounds = bounds['b']

# Metadata payload for train(...):
# - bounds are source-of-truth state support
# - master_seed is the data-generation seed (runtime training seed is set in OptimizationConfig)
dataset_metadata = {
    'bounds': {
        'k': [float(k_bounds[0]), float(k_bounds[1])],
        'log_z': [float(logz_bounds[0]), float(logz_bounds[1])],
        'b': [float(b_bounds[0]), float(b_bounds[1])],
    },
    'master_seed': [int(data_config.master_seed[0]), int(data_config.master_seed[1])],
}

print(f"\nBounds: k={k_bounds}, log_z={logz_bounds}, b={b_bounds}")
print(f"Master seed for data generation: {tuple(dataset_metadata['master_seed'])}")
print("\nNote: All scenarios will use this same dataset for training.")
# Out:
# Training: 400 trajectories, 40,000 transitions
# Validation: 400 trajectories, 40,000 transitions
#
# Bounds: k=(15.447022976557044, 308.94045953114085), log_z=(-0.6301260378126043, 0.6301260378126043), b=(0.0, 188.9954691887226)
# Master seed for data generation: (20, 26)
#
# Note: All scenarios will use this same dataset for training.

# %%
# =============================================================================
# 1.7 Data Format Comparison (Visualization)
# =============================================================================

plot_path = os.path.join(FIGURES_DIR, "data_format_comparison.png")

# Compare data formats visually
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

# Plot 1: Trajectory z_path (first 5 paths)
z_path = traj_data['z_path'].numpy()
for i in range(min(5, z_path.shape[0])):
    axes[0].plot(z_path[i], alpha=0.7, label=f'Path {i+1}')
axes[0].set_title('Trajectory Data: z_path (5 samples)')
axes[0].set_xlabel('Time Step')
axes[0].set_ylabel('Productivity z')
axes[0].legend(fontsize=8)
axes[0].grid(True, alpha=0.3)

# Plot 2: Flattened z distribution
z_flat = flat_data['z'].numpy()
axes[1].hist(z_flat, bins=50, alpha=0.7, color='steelblue', edgecolor='black')
axes[1].set_title(f'Flattened Data: z distribution ({len(z_flat)} transitions)')
axes[1].set_xlabel('Productivity z')
axes[1].set_ylabel('Count')
axes[1].grid(True, alpha=0.3)

# Plot 3: Flattened k distribution (independent sampling)
k_flat = flat_data['k'].numpy()
k_traj = traj_data['k0'].numpy()
axes[2].hist(k_flat, bins=50, alpha=0.7, label='Flattened k (independent)', color='orange', edgecolor='black')
axes[2].hist(k_traj, bins=30, alpha=0.7, label='Trajectory k0', color='green', edgecolor='black')
axes[2].set_title('Capital Distribution Comparison')
axes[2].set_xlabel('Capital k')
axes[2].set_ylabel('Count')
axes[2].legend()
axes[2].grid(True, alpha=0.3)

# Save and display
print(f"Saving figure to {plot_path}...")
fig.savefig(plot_path, dpi=300, bbox_inches='tight')
plt.tight_layout()
plt.show()

print("\nKey Observations:")
print("  - Trajectory data: Time-dependent paths (left)")
print("  - Flattened data: i.i.d. transitions (middle, right)")
print("  - Independent k: Uniformly distributed across state space")
# Out:
# Saving figure to ../results/run-20260221-185122/figures/data_format_comparison.png...
# Key Observations:
#   - Trajectory data: Time-dependent paths (left)
#   - Flattened data: i.i.d. transitions (middle, right)
#   - Independent k: Uniformly distributed across state space

# %%
# =============================================================================
# 1.8 Dataset Statistics
# =============================================================================

from src.utils.analysis import summarize_batch

# Print numerical stats of a single batch
summarize_batch(traj_data, batch_idx=0)
# Out:
# Batch 0 Summary:
# ------------------------------------------------------------
# k0         shape=(400,)          mean=163.8922 std=86.7409 min=15.6189 max=308.8474
# z0         shape=(400,)          mean=1.0927 std=0.3765 min=0.5367 max=1.8680
# b0         shape=(400,)          mean=96.6224 std=55.3777 min=1.1634 max=188.8016
# z_path     shape=(400, 101)      mean=1.0270 std=0.2254 min=0.4111 max=2.8069

# %% [markdown]
# ---
#
# # Section 2: Training
#
# This section trains all models and saves checkpoints to disk.
#
# **Note:** This section depends on Section 1 (dataset must be in memory).

# %% [markdown]
# ## 2.1 Shared Training Configuration
#
# Configuration shared across all scenarios (network architecture, optimization settings, etc.).

# %%
# =============================================================================
# 2.1.1 Shared Training Configuration
# =============================================================================

# Network Architecture (shared across all methods)
# Compact ablation switch: support-aware normalization + affine-exp policy head.
USE_SUPPORT_AFFINE_HEAD = True

if USE_SUPPORT_AFFINE_HEAD:
    net_config = NetworkConfig(
        n_layers=2,
        n_neurons=32,
        hidden_activation="relu",
        basic_policy_head="affine_exp",
        risky_policy_k_head="affine_exp",
        risky_policy_b_head="bounded_sigmoid",
        observation_normalization=ObservationNormalizationConfig(
            k_scheme="log_zscore",
            z_scheme="zscore",
            b_scheme="zscore",
            z_input_space="level",  # dataset z is in levels
        ),
    )
else:
    net_config = NetworkConfig(
        n_layers=2,
        n_neurons=32,
        hidden_activation="swish",
    )

# Runtime seed for model initialization and training-time RNG
TRAINING_SEED = tuple(dataset_metadata["master_seed"])

# Optimization Settings (using config from Section 1.3)
opt_config = OptimizationConfig(
    batch_size=TRAIN_BATCH_SIZE,
    n_iter=TRAIN_N_ITER,
    learning_rate=1e-3,
    learning_rate_critic=5e-3,
    log_every=50,
    training_seed=TRAINING_SEED,
    deterministic_ops=True,
    early_stopping=EarlyStoppingConfig(
        enabled=True,
        patience=5,
        eval_freq=50,
        lr_epsilon=1e-2,
        lr_window=10,
        er_epsilon=1e-2,
        br_critic_epsilon=1e-3,
        br_actor_epsilon=1e-3
    ),
    optimizer=OptimizerConfig(clipnorm=2.0)
)

# Temperature Annealing Schedule (shared)
anneal_config = AnnealingConfig(
    temperature_init=1.0,
    temperature_min=1e-4,
    decay=TRAIN_DECAY
)

# Warm-start policy source for BR methods
# LR/ER stay random-init; BR methods initialize from this trained baseline policy.
BR_WARM_START_SOURCE = 'er'
BR_METHODS = {'br', 'br_multitask'}
BASELINE_WARM_START_RULE = {
    'lr': None,
    'er': None,
    'br': BR_WARM_START_SOURCE,
}

# Method-specific configurations (canonical BR module names)
method_configs = {
    'lr': MethodConfig(name="basic_lr"),
    'er': MethodConfig(name="basic_er", polyak_tau=0.995, loss_type="crossprod"),
    'br': MethodConfig(
        name="basic_br_actor_critic",
        n_critic=5,
        polyak_tau=0.995,
        loss_type="mse", # Biased but stable; standard TD-style default for actor-critic
        br_normalization="frictionless",
    ),
}

print("Shared training configuration loaded.")
print(f"  Network: {net_config.n_layers} layers, {net_config.n_neurons} neurons, {net_config.hidden_activation}")
print(f"  Optimization: batch_size={opt_config.batch_size}, n_iter={opt_config.n_iter}")
print(f"  Methods: {list(method_configs.keys())}")
print("  Loss types:")
print(f"    er: {method_configs['er'].loss_type}")
print(f"    br: {method_configs['br'].loss_type}")
print("  Warm-start rule (baseline):")
for method_name in ['lr', 'er', 'br']:
    source = BASELINE_WARM_START_RULE[method_name]
    if source is None:
        print(f"    {method_name}: random init")
    else:
        print(f"    {method_name}: warm start from {source}")
# Out:
# Shared training configuration loaded.
#   Network: 2 layers, 32 neurons, relu
#   Optimization: batch_size=64, n_iter=1000
#   Methods: ['lr', 'er', 'br']
#   Loss types:
#     er: crossprod
#     br: mse
#   Warm-start rule (baseline):
#     lr: random init
#     er: random init
#     br: warm start from er

# %% [markdown]
# ## 2.2 Baseline Training & Validation
#
# **Train baseline (no adjustment costs) first to verify the training pipeline works.**
#
# This section:
# 1. Trains all 4 methods (LR, ER, BR actor-critic, BR multitask) on the baseline scenario only
# 2. Validates against the frictionless analytical solution
# 3. Provides quick diagnostic plots
#
# Once baseline is working correctly, proceed to Section 2.3 for all scenarios.

# %%
# =============================================================================
# 2.2.1 Baseline Setup (Reusable)
# =============================================================================

baseline_params = BASIC_SCENARIOS['baseline']['params']

print(f"Baseline params: cost_convex={baseline_params.cost_convex}, cost_fixed={baseline_params.cost_fixed}")
print("Run LR and ER first (random init), then BR methods (warm-started).")
print("Explicit warm-start rule:")
for method_name in ['lr', 'er', 'br']:
    source = BASELINE_WARM_START_RULE[method_name]
    if source is None:
        print(f"  {method_name}: random init")
    else:
        print(f"  {method_name}: warm start from {source}")

if 'results_baseline' not in globals() or not isinstance(results_baseline, dict):
    results_baseline = {}

# Data format for each method
baseline_data_format = {
    'lr': (traj_data, val_traj),              # LR uses trajectory data
    'er': (flat_data, val_flat),              # ER uses flattened data
    'br': (flat_data, val_flat),              # BR actor-critic uses flattened data
}


def _resolve_warm_start_policy(warm_start_source, scenario_results):
    if warm_start_source is None:
        return None

    if warm_start_source not in scenario_results:
        raise RuntimeError(
            f"Warm start source '{warm_start_source}' is not trained yet. "
            "Train the source method first."
        )

    return scenario_results[warm_start_source]


def train_baseline_method(method_name: str, warm_start_source=None):
    if method_name not in method_configs:
        raise KeyError(f"Unknown method: {method_name}")

    method_config = method_configs[method_name]
    dataset, val_data = baseline_data_format[method_name]

    print(f"\n{'=' * 60}")
    print(f"Training baseline/{method_name}...")
    print(f"{'=' * 60}")

    exp_config = ExperimentConfig(
        name=f"basic_baseline_{method_name}",
        params=baseline_params,
        shock_params=shock_params,
        network=net_config,
        optimization=opt_config,
        annealing=anneal_config,
        method=method_config,
    )

    warm_start_policy = _resolve_warm_start_policy(warm_start_source, results_baseline)
    if warm_start_source is None:
        print("  Warm start policy: None (random init)")
    else:
        print(f"  Warm start policy: {warm_start_source}")

    result = train(
        model='basic',
        method=method_name,
        config=exp_config,
        train_data=dataset,
        dataset_metadata=dataset_metadata,
        validation_data=val_data,
        warm_start_policy=warm_start_policy,
        return_legacy_dict=True,
    )

    results_baseline[method_name] = result

    if method_name == 'lr':
        print(f"  Final LR loss: {result['history']['loss_LR'][-1]:.6f}")
    elif method_name == 'er':
        print(f"  Final ER loss: {result['history']['loss_ER'][-1]:.6f}")
    elif method_name == 'br':
        print(f"  Final BR critic loss: {result['history']['loss_critic'][-1]:.6f}")

    warm_meta = result.get('_meta', {})
    if warm_meta.get('warm_start_applied', False):
        print(f"  Warm start applied from: {warm_meta.get('warm_start_source')}")

    print(f"  Baseline methods available: {sorted(results_baseline.keys())}")
    return result
# Out:
# Baseline params: cost_convex=0.0, cost_fixed=0.0
# Run LR and ER first (random init), then BR methods (warm-started).
# Explicit warm-start rule:
#   lr: random init
#   er: random init
#   br: warm start from er

# %%
# =============================================================================
# 2.2.2 Train Baseline: LR
# =============================================================================

result_lr = train_baseline_method('lr', warm_start_source=BASELINE_WARM_START_RULE['lr'])
# Out:
# ============================================================
# Training baseline/lr...
# ============================================================
#   Warm start policy: None (random init)
# [INFO] core: Starting Training Loop: Method=basic_lr, Iterations=1000, EarlyStopping=enabled
# [INFO] core: Dataset format validation passed for basic_lr
# [INFO] core: Convergence checker created. N_anneal=2297, Patience=5
# [INFO] core: Iter 50: LR=-345.8401 train/lr_loss=-345.8401 Temp (log10)=-0.11
# [INFO] core: Iter 100: LR=-377.8103 train/lr_loss=-377.8103 Temp (log10)=-0.22
# [INFO] core: Iter 150: LR=-358.9603 train/lr_loss=-358.9603 Temp (log10)=-0.32
# [INFO] core: Iter 200: LR=-395.5896 train/lr_loss=-395.5896 Temp (log10)=-0.43
# [INFO] core: Iter 250: LR=-376.6431 train/lr_loss=-376.6431 Temp (log10)=-0.54
# [INFO] core: Iter 300: LR=-343.6968 train/lr_loss=-343.6968 Temp (log10)=-0.65
# [INFO] core: Iter 350: LR=-342.9669 train/lr_loss=-342.9669 Temp (log10)=-0.76
# [INFO] core: Iter 400: LR=-348.6651 train/lr_loss=-348.6651 Temp (log10)=-0.87
# [INFO] core: Iter 450: LR=-377.8525 train/lr_loss=-377.8525 Temp (log10)=-0.98
# [INFO] core: Iter 500: LR=-359.0049 train/lr_loss=-359.0049 Temp (log10)=-1.09
# [INFO] core: Iter 550: LR=-395.5899 train/lr_loss=-395.5899 Temp (log10)=-1.20
# [INFO] core: Iter 600: LR=-376.6550 train/lr_loss=-376.6550 Temp (log10)=-1.30
# [INFO] core: Iter 650: LR=-343.7233 train/lr_loss=-343.7233 Temp (log10)=-1.41
# [INFO] core: Iter 700: LR=-342.9690 train/lr_loss=-342.9690 Temp (log10)=-1.52
# [INFO] core: Iter 750: LR=-348.6758 train/lr_loss=-348.6758 Temp (log10)=-1.63
# [INFO] core: Iter 800: LR=-377.8585 train/lr_loss=-377.8585 Temp (log10)=-1.74
# [INFO] core: Iter 850: LR=-359.0119 train/lr_loss=-359.0119 Temp (log10)=-1.85
# [INFO] core: Iter 900: LR=-395.5869 train/lr_loss=-395.5869 Temp (log10)=-1.96
# [INFO] core: Iter 950: LR=-376.6596 train/lr_loss=-376.6596 Temp (log10)=-2.07
# [INFO] core: Iter 1000: LR=-343.7405 train/lr_loss=-343.7405 Temp (log10)=-2.17
# [INFO] core: Training finished in 1127.36s (stopped_early=False)
#   Final LR loss: -343.740479
#   Baseline methods available: ['br', 'er', 'lr']

# %%
# =============================================================================
# 2.2.3 Train Baseline: ER
# =============================================================================

result_er = train_baseline_method('er', warm_start_source=BASELINE_WARM_START_RULE['er'])
# Out:
# ============================================================
# Training baseline/er...
# ============================================================
#   Warm start policy: None (random init)
# [INFO] core: Starting Training Loop: Method=basic_er, Iterations=1000, EarlyStopping=enabled
# [INFO] core: Dataset format validation passed for basic_er
# [INFO] core: Convergence checker created. N_anneal=2297, Patience=5
# [INFO] core: Iter 50: ER=0.0003 train/er_loss=0.0003 Temp (log10)=-0.11
# [INFO] core: Iter 100: ER=0.0001 train/er_loss=0.0001 Temp (log10)=-0.22
# [INFO] core: Iter 150: ER=-0.0001 train/er_loss=-0.0001 Temp (log10)=-0.32
# [INFO] core: Iter 200: ER=-0.0000 train/er_loss=-0.0000 Temp (log10)=-0.43
# [INFO] core: Iter 250: ER=0.0000 train/er_loss=0.0000 Temp (log10)=-0.54
# [INFO] core: Iter 300: ER=-0.0000 train/er_loss=-0.0000 Temp (log10)=-0.65
# [INFO] core: Iter 350: ER=-0.0000 train/er_loss=-0.0000 Temp (log10)=-0.76
# [INFO] core: Iter 400: ER=-0.0000 train/er_loss=-0.0000 Temp (log10)=-0.87
# [INFO] core: Iter 450: ER=-0.0001 train/er_loss=-0.0001 Temp (log10)=-0.98
# [INFO] core: Iter 500: ER=0.0000 train/er_loss=0.0000 Temp (log10)=-1.09
# [INFO] core: Iter 550: ER=0.0000 train/er_loss=0.0000 Temp (log10)=-1.20
# [INFO] core: Iter 600: ER=-0.0001 train/er_loss=-0.0001 Temp (log10)=-1.30
# [INFO] core: Iter 650: ER=-0.0001 train/er_loss=-0.0001 Temp (log10)=-1.41
# [INFO] core: Iter 700: ER=-0.0000 train/er_loss=-0.0000 Temp (log10)=-1.52
# [INFO] core: Iter 750: ER=-0.0000 train/er_loss=-0.0000 Temp (log10)=-1.63
# [INFO] core: Iter 800: ER=-0.0001 train/er_loss=-0.0001 Temp (log10)=-1.74
# [INFO] core: Iter 850: ER=-0.0001 train/er_loss=-0.0001 Temp (log10)=-1.85
# [INFO] core: Iter 900: ER=-0.0000 train/er_loss=-0.0000 Temp (log10)=-1.96
# [INFO] core: Iter 950: ER=-0.0001 train/er_loss=-0.0001 Temp (log10)=-2.07
# [INFO] core: Iter 1000: ER=0.0001 train/er_loss=0.0001 Temp (log10)=-2.17
# [INFO] core: Training finished in 66.92s (stopped_early=False)
#   Final ER loss: 0.000087
#   Baseline methods available: ['br', 'er', 'lr']

# %%
# =============================================================================
# 2.2.4 Train Baseline: BR Actor-Critic (Warm-Started from ER)
# =============================================================================

result_br = train_baseline_method('br', warm_start_source=BASELINE_WARM_START_RULE['br'])
# Out:
# ============================================================
# Training baseline/br...
# ============================================================
#   Warm start policy: er
# [INFO] core: Starting Training Loop: Method=basic_br_actor_critic, Iterations=1000, EarlyStopping=enabled
# [INFO] core: Dataset format validation passed for basic_br_actor_critic
# [INFO] core: Convergence checker created. N_anneal=2297, Patience=5
# [INFO] core: Iter 50: actor/loss=-102.3651 critic/loss=0.0022 actor=-102.3651 rel_mse=0.241291 Temp (log10)=-0.11
# [INFO] core: Iter 100: actor/loss=-148.3535 critic/loss=0.0017 actor=-148.3535 rel_mse=0.063372 Temp (log10)=-0.22
# [INFO] core: Iter 150: actor/loss=-139.5607 critic/loss=0.0013 actor=-139.5607 rel_mse=0.418508 Temp (log10)=-0.32
# [INFO] core: Iter 200: actor/loss=-145.1356 critic/loss=0.0010 actor=-145.1356 rel_mse=0.195352 Temp (log10)=-0.43
# [INFO] core: Iter 250: actor/loss=-151.1819 critic/loss=0.0009 actor=-151.1819 rel_mse=0.018880 Temp (log10)=-0.54
# [INFO] core: Iter 300: actor/loss=-145.9343 critic/loss=0.0005 actor=-145.9343 rel_mse=0.058381 Temp (log10)=-0.65
# [INFO] core: Iter 350: actor/loss=-165.7120 critic/loss=0.0002 actor=-165.7120 rel_mse=0.034932 Temp (log10)=-0.76
# [INFO] core: Iter 400: actor/loss=-147.6712 critic/loss=0.0002 actor=-147.6712 rel_mse=0.020073 Temp (log10)=-0.87
# [INFO] core: Iter 450: actor/loss=-151.0681 critic/loss=0.0002 actor=-151.0681 rel_mse=0.073788 Temp (log10)=-0.98
# [INFO] core: Iter 500: actor/loss=-163.2111 critic/loss=0.0002 actor=-163.2111 rel_mse=0.010518 Temp (log10)=-1.09
# [INFO] core: Iter 550: actor/loss=-182.2922 critic/loss=0.0003 actor=-182.2922 rel_mse=0.005832 Temp (log10)=-1.20
# [INFO] core: Iter 600: actor/loss=-156.6355 critic/loss=0.0004 actor=-156.6355 rel_mse=0.002369 Temp (log10)=-1.30
# [INFO] core: Iter 650: actor/loss=-165.8389 critic/loss=0.0005 actor=-165.8389 rel_mse=0.006840 Temp (log10)=-1.41
# [INFO] core: Iter 700: actor/loss=-157.2260 critic/loss=0.0006 actor=-157.2260 rel_mse=0.012112 Temp (log10)=-1.52
# [INFO] core: Iter 750: actor/loss=-191.9913 critic/loss=0.0011 actor=-191.9913 rel_mse=0.014224 Temp (log10)=-1.63
# [INFO] core: Iter 800: actor/loss=-162.4466 critic/loss=0.0008 actor=-162.4466 rel_mse=0.007442 Temp (log10)=-1.74
# [INFO] core: Iter 850: actor/loss=-174.7416 critic/loss=0.0007 actor=-174.7416 rel_mse=0.011037 Temp (log10)=-1.85
# [INFO] core: Iter 900: actor/loss=-184.0838 critic/loss=0.0012 actor=-184.0838 rel_mse=0.006353 Temp (log10)=-1.96
# [INFO] core: Iter 950: actor/loss=-173.3134 critic/loss=0.0017 actor=-173.3134 rel_mse=0.006624 Temp (log10)=-2.07
# [INFO] core: Iter 1000: actor/loss=-207.1714 critic/loss=0.0013 actor=-207.1714 rel_mse=0.005059 Temp (log10)=-2.17
# [INFO] core: Training finished in 291.54s (stopped_early=False)
#   Final BR critic loss: 0.001339
#   Warm start applied from: dict['_policy_net']:BasicPolicyNetwork
#   Baseline methods available: ['br', 'er', 'lr']

# %%
# =============================================================================
# 2.2.6 Quick Baseline Validation (Compare to Analytical Solution)
# =============================================================================

from src.utils.plotting import plot_baseline_policy_validation

fig, baseline_meta = plot_baseline_policy_validation(
    results_baseline=results_baseline,
    baseline_params=baseline_params,
    shock_params=shock_params,
    k_bounds=k_bounds,
    ref_method='er',
    logz_bounds=logz_bounds,
    methods=['lr', 'er', 'br_multitask', 'br'],
    ncols=2,
    save_path=os.path.join(FIGURES_DIR, 'baseline_validation.png'),
)
plt.show()

print(f"\nNote: All values are in LEVELS (k_bounds = {k_bounds})")
print(f"Fixed k at {baseline_meta['ref_method'].upper()} k* = {baseline_meta['k_star']:.4f}")
print(f"Methods requested: {baseline_meta['methods_requested']}")
print(f"Methods plotted: {baseline_meta['methods_plotted']}")
print("\nIf networks match the analytical solution (dashed line), training is working!")
# Out:
# /var/folders/8m/_52z3gvn0p58rgf1n5r1tw5h0000gn/T/ipykernel_61335/2176530071.py:7: RuntimeWarning: plot_baseline_policy_validation: argument 'ncols' is ignored in the new rows layout.
#   fig, baseline_meta = plot_baseline_policy_validation(
# /var/folders/8m/_52z3gvn0p58rgf1n5r1tw5h0000gn/T/ipykernel_61335/2176530071.py:7: RuntimeWarning: plot_baseline_policy_validation: missing methods are skipped in rows layout: ['br_multitask']
#   fig, baseline_meta = plot_baseline_policy_validation(
# Note: All values are in LEVELS (k_bounds = (15.447022976557044, 308.94045953114085))
# Fixed k at ER k* = 85.1803
# Methods requested: ['lr', 'er', 'br_multitask', 'br']
# Methods plotted: ['lr', 'er', 'br']
#
# If networks match the analytical solution (dashed line), training is working!

# %% [markdown]
# ## 2.4 Risky Debt Model Training
#
# Single baseline scenario with BR method only.

# %%
# =============================================================================
# 2.4.1 Risky Debt Configuration and Training
# =============================================================================

# Store risky results: results_risky[scenario_name] = result_dict
results_risky = {}

# Risky-specific method config (MSE default for stability; optional 'huber')
method_config_risky = MethodConfig(
    name="risky_br_actor_critic",
    n_critic=10,
    polyak_tau=0.995,
    loss_type="mse",
    br_normalization="frictionless",
    risky=RiskyDebtConfig(
        weight_br=0.1,
        loss_type="mse"
    )
)

# Risky-specific annealing (tighter logit_clip)
anneal_config_risky = AnnealingConfig(
    temperature_init=1.0,
    temperature_min=1e-4,
    decay=0.995,  # Use profile config
    logit_clip=5.0
)


# Risky-specific optimization (uses profile config)
opt_config_risky = OptimizationConfig(
    batch_size=TRAIN_RISKY_BATCH_SIZE,
    n_iter=TRAIN_RISKY_N_ITER,
    learning_rate=1e-4,
    learning_rate_critic=1e-3,
    log_every=50,
    training_seed=TRAINING_SEED,
    deterministic_ops=True,
    early_stopping=EarlyStoppingConfig(
        enabled=True,
        patience=5,
        eval_freq=50,
        br_critic_epsilon=1e-5,
        br_actor_epsilon=1e-4
    ),
    optimizer=OptimizerConfig(clipnorm=1.0)
)

# Loop over economic scenarios for risky debt
for scenario_name, scenario in RISKY_SCENARIOS.items():
    print(f"\n{'#' * 70}")
    print(f"# RISKY DEBT SCENARIO: {scenario_name}")
    print(f"# {scenario['description']}")
    print(f"{'#' * 70}")

    print(f"\nTraining Risky Debt BR Method...")
    exp_config_risky = ExperimentConfig(
        name=f"risky_{scenario_name}_br",
        params=scenario['params'],
        shock_params=shock_params,
        network=net_config,
        optimization=opt_config_risky,
        annealing=anneal_config_risky,
        method=method_config_risky,
    )

    result = train(
        model='risky',
        method='br',
        config=exp_config_risky,
        train_data=flat_data,
        dataset_metadata=dataset_metadata,
        return_legacy_dict=True,
    )

    results_risky[scenario_name] = result

    print(f"\n  Final critic loss: {result['history']['loss_critic'][-1]:.6f}")
    print(f"  Final actor loss:  {result['history']['loss_actor'][-1]:.6f}")
    print(f"  Final price loss:  {result['history']['loss_price'][-1]:.6f}")

print(f"\n{'=' * 70}")
print(f"RISKY DEBT TRAINING COMPLETE: {len(results_risky)} scenarios")
print(f"{'=' * 70}")

# %%
# =============================================================================
# 2.4.2 Risky Debt Training Diagnostics
# =============================================================================

from src.utils.analysis import print_training_summary

# Print summary table first
print_training_summary(results_risky, model_type="risky")

# Plot training diagnostics for risky debt (2x3 panel)
fig, axes = plt.subplots(2, 3, figsize=(15, 10))
colors = plt.cm.tab10.colors

for idx, (scenario_name, result) in enumerate(results_risky.items()):
    color = colors[idx % len(colors)]
    history = result['history']
    iters = history.get('iteration', list(range(len(history['loss_actor']))))
    
    # Row 1: Loss curves
    axes[0, 0].plot(iters, history['loss_critic'], 
                    label=scenario_name, color=color, alpha=0.8)
    axes[0, 1].plot(iters, history['loss_actor'], label=scenario_name, color=color, alpha=0.8)
    axes[0, 2].plot(iters, history['loss_price'], label=scenario_name, color=color, alpha=0.8)
    
    # Row 2: Scale and constraint diagnostics
    if 'mean_value_scale' in history:
        axes[1, 0].plot(iters, history['mean_value_scale'], label=scenario_name, color=color, alpha=0.8)
    if 'frac_b_at_limit' in history:
        axes[1, 1].plot(iters, history['frac_b_at_limit'], label=scenario_name, color=color, alpha=0.8)
    if 'frac_default_hard' in history:
        axes[1, 2].plot(iters, history['frac_default_hard'], label=f'{scenario_name} (hard)', 
                       color=color, alpha=0.8)
    if 'mean_p_default' in history:
        axes[1, 2].plot(iters, history['mean_p_default'], label=f'{scenario_name} (soft)', 
                       color=color, linestyle='--', alpha=0.8)

# Configure panels
panel_config = [
    (axes[0, 0], 'Critic Loss (actual)', 'Loss'),
    (axes[0, 1], 'Actor Loss', 'Loss'),
    (axes[0, 2], 'Price Loss', 'Loss'),
    (axes[1, 0], 'Value Scale Growth', 'Mean |V|'),
    (axes[1, 1], 'Debt Constraint Binding', 'Fraction'),
    (axes[1, 2], 'Default Rates', 'Rate'),
]
for ax, title, ylabel in panel_config:
    ax.set_title(title, fontsize=11, fontweight='bold')
    ax.set_xlabel('Iteration')
    ax.set_ylabel(ylabel)
    ax.legend(fontsize=8)
    ax.grid(True, alpha=0.3)

axes[1, 1].set_ylim([0, 1])
axes[1, 2].set_ylim([0, 1])

fig.suptitle('Risky Debt BR Training Diagnostics', fontweight='bold', fontsize=14)
plt.tight_layout()
plt.savefig(os.path.join(FIGURES_DIR, 'risky_debt_diagnostics.png'), dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 2.5 Save Checkpoints
#
# Save all training results with hierarchical structure:
#
# - `results/latest/` symlink (stable path)
# - `run/YYMMDD-HHMMSS` where the actual results are stored (timestamped for each run)

# %%
# =============================================================================
# 2.4.1 Save All Training Results with Hierarchical Structure
# =============================================================================

import json
import dataclasses
from src.utils.checkpointing import save_training_result

# Save basic model results: checkpoints/basic/{scenario}/{method}
print("=" * 70)
print("SAVING BASIC MODEL RESULTS")
print("=" * 70)

basic_dir = os.path.join(CHECKPOINTS_DIR, "basic")
for scenario_name, scenario_results in results_basic.items():
    scenario_dir = os.path.join(basic_dir, scenario_name)
    print(f"\nScenario: {scenario_name}")
    
    for method_name, result in scenario_results.items():
        save_training_result(
            result=result,
            save_dir=scenario_dir,
            name=method_name,
            overwrite=True,
            verbose=False
        )
        print(f"  Saved {method_name} -> {scenario_dir}/{method_name}/")
    
    # Save scenario-specific params alongside the checkpoint
    scenario_params = BASIC_SCENARIOS[scenario_name]['params']
    params_to_save = {
        'params': dataclasses.asdict(scenario_params),
        'shock_params': dataclasses.asdict(shock_params)
    }
    params_path = os.path.join(scenario_dir, 'params.json')
    with open(params_path, 'w') as f:
        json.dump(params_to_save, f, indent=2)
    print(f"  Saved params -> {params_path}")

# Save risky model results: checkpoints/risky/{scenario}
print("\n" + "=" * 70)
print("SAVING RISKY DEBT RESULTS")
print("=" * 70)

risky_dir = os.path.join(CHECKPOINTS_DIR, "risky")
for scenario_name, result in results_risky.items():
    scenario_dir = os.path.join(risky_dir, scenario_name)
    save_training_result(
        result=result,
        save_dir=risky_dir,
        name=scenario_name,
        overwrite=True,
        verbose=False
    )
    print(f"  Saved {scenario_name} -> {risky_dir}/{scenario_name}/")
    
    # Save scenario-specific params alongside the checkpoint
    scenario_params = RISKY_SCENARIOS[scenario_name]['params']
    params_to_save = {
        'params': dataclasses.asdict(scenario_params),
        'shock_params': dataclasses.asdict(shock_params)
    }
    # For risky, the checkpoint is saved as risky/{scenario_name}/, so put params.json there
    params_path = os.path.join(risky_dir, scenario_name, 'params.json')
    with open(params_path, 'w') as f:
        json.dump(params_to_save, f, indent=2)
    print(f"  Saved params -> {params_path}")

# Save scenario definitions for Section 3
scenarios_meta = {
    'basic_scenarios': list(BASIC_SCENARIOS.keys()),
    'risky_scenarios': list(RISKY_SCENARIOS.keys()),
    'methods': list(method_configs.keys())
}

meta_path = os.path.join(CHECKPOINTS_DIR, 'scenarios.json')
with open(meta_path, 'w') as f:
    json.dump(scenarios_meta, f, indent=2)

print(f"\nScenario metadata saved to {meta_path}")
print("\n" + "=" * 70)
print("ALL CHECKPOINTS SAVED")
print("=" * 70)

# %%
# =============================================================================
# 2.4.2 Save Bounds (needed for policy evaluation in Section 3)
# =============================================================================

import json

bounds_to_save = {
    'k': list(bounds['k']),
    'log_z': list(bounds['log_z']),
    'b': list(bounds['b'])
}

bounds_path = os.path.join(CHECKPOINTS_DIR, 'bounds.json')
with open(bounds_path, 'w') as f:
    json.dump(bounds_to_save, f, indent=2)

print(f"Bounds saved to {bounds_path}")
print("\nSection 2 complete. You can now restart the kernel and run Section 3 independently.")

# %% [markdown]
# ## Training Complete!
#
# All checkpoints have been saved to `results/{RUN_NAME}/checkpoints/`.
#
# **Next step:** Open `02_part1_results.ipynb` to generate all figures from the saved checkpoints.
